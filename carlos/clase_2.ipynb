# %%
# lenguajes compilados (c, c++, java) e interpretado (python, javascript)
# https://www.freecodecamp.org/espanol/news/lenguajes-compilados-vs-interpretados/#:~:text=En%20un%20lenguaje%20compilado%2C%20la,el%20c%C3%B3digo%20y%20lo%20ejecuta.
x = 1 # -> interprete -> assembler
print(x, type(x))
x = "algo" # tipado dinámico
print(x, type(x))
y = 0
# x / y
# Out:
# 1 <class 'int'>
# algo <class 'str'>

# %%
# diccionario
dictionary = {
    "name": "valentina",
    "lastname": "arenas",
    "age": 25,
    0: "cero"
}
dictionary
# Out:
# {'name': 'valentina', 'lastname': 'arenas', 'age': 25, 0: 'cero'}

# %%
print(dictionary.keys())
print(dictionary.values())
print(dictionary["name"])
print(dictionary[0])
# Out:
# dict_keys(['name', 'lastname', 'age', 0])
# dict_values(['valentina', 'arenas', 25, 'cero'])
# valentina
# cero

# %%
students = [
    {
        "name": "valentina",
        "lastname": "arenas",
        ("classes", 0): ["python", "scala"]
    },
    {
        "name": "juan",
        "lastname": "perez",
        ("classes", 0): ["python", "java"],
        True: "algo"
    }
]
students
# Out:
# [{'name': 'valentina',
#   'lastname': 'arenas',
#   ('classes', 0): ['python', 'scala']},
#  {'name': 'juan',
#   'lastname': 'perez',
#   ('classes', 0): ['python', 'java'],
#   True: 'algo'}]

# %%
print(type(students))
print(students[0])
print(type(students[0]))
print(students[0].keys())
print(type(students[0].keys()))
print(list(students[0].keys())[2])
print(type(list(students[0].keys())[2]))
print(students[0][('classes', 0)])
print(type(students[0][('classes', 0)]))
print(students[0][('classes', 0)][0])
# Out:
# <class 'list'>
# {'name': 'valentina', 'lastname': 'arenas', ('classes', 0): ['python', 'scala']}
# <class 'dict'>
# dict_keys(['name', 'lastname', ('classes', 0)])
# <class 'dict_keys'>
# ('classes', 0)
# <class 'tuple'>
# ['python', 'scala']
# <class 'list'>
# python

# %%
# listas/diccionarios comprensivos
listica = []

for j in range(5):
    for i in range(5):
        if i*j % 2 == 0:
            listica.append(i*j)

print(listica)
print(len(listica))

listica = [i*j for j in range(5) for i in range(5) if i*j % 2 == 0]
print(listica)
print(len(listica))
# Out:
# [0, 0, 0, 0, 0, 0, 2, 4, 0, 2, 4, 6, 8, 0, 6, 12, 0, 4, 8, 12, 16]
# 21
# [0, 0, 0, 0, 0, 0, 2, 4, 0, 2, 4, 6, 8, 0, 6, 12, 0, 4, 8, 12, 16]
# 21

# %%
names = [s["name"] for s in students]
names
# for s in students:
#     print(s["name"])
# Out:
# ['valentina', 'juan']

# %%
student = students[0]
listica = [
    f"{key}: {value}"
    for key, value in student.items()
    if type(key) == str
]
dictionario = {
    key: value
    for key, value in student.items()
    if type(key) == str
}
print(listica)
print(dictionario)
# for key, value in student.items():
#     if type(key) == str:
#         print(f"{key}: {value}")
# Out:
# ['name: valentina', 'lastname: arenas']
# {'name': 'valentina', 'lastname': 'arenas'}

# %%
datos = {
    i: [j for j in range(5)]
    for i in range(5)
    if i % 2 == 0
}
datos
# Out:
# [[0, 0, 0, 0, 0], [0, 2, 4, 6, 8], [0, 4, 8, 12, 16]]

# %%
# pandas, numpy, matplotlib
# excel, matematica, visualizaciones
import numpy as np

print([1,2,3] + [1,2,3])
print(np.array([1,2,3]) + np.array([1,2,3]))
# Out:
# [1, 2, 3, 1, 2, 3]
# [2 4 6]

# %%
import pandas as pd
# path = "ventas.xlsx"
# df = pd.read_excel(path)
import random
df = pd.DataFrame({f"col_{i+1}": [random.randint(1,5) for _ in range(200)] for i in range(5)})

# %%
df
# Out:
#      col_1  col_2  col_3  col_4  col_5
# 0        2      1      2      1      2
# 1        5      4      3      2      5
# 2        1      3      3      5      4
# 3        4      1      3      1      4
# 4        1      4      3      4      1
# ..     ...    ...    ...    ...    ...
# 195      3      2      4      5      5
# 196      4      2      5      1      5
# 197      4      5      3      2      2
# 198      1      2      2      2      4
# 199      2      2      5      3      5
#
# [200 rows x 5 columns]

# %%
df["col_1"].unique()
# Out:
# array([2, 5, 1, 4, 3])

# %%
df["col_1"].value_counts().sort_index().sort_values(ascending=False)
# Out:
# col_1
# 1    52
# 4    43
# 5    42
# 2    40
# 3    23
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#             col_1       col_2       col_3       col_4       col_5
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     2.915000    3.130000    3.120000    2.930000    3.185000
# std      1.516335    1.393849    1.412649    1.416025    1.453042
# min      1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      1.000000    2.000000    2.000000    2.000000    2.000000
# 50%      3.000000    3.000000    3.000000    3.000000    3.000000
# 75%      4.000000    4.000000    4.000000    4.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000

# %%
import matplotlib.pyplot as plt

data = df["col_1"].value_counts().sort_index()
x = data.index
y = data.values

plt.scatter(x, y)
plt.show()
